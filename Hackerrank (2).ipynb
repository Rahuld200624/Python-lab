# %%
n = int(input("Enter a number: "))

if n % 2 != 0:
    print("Weird")
else:
    if 2 <= n <= 5:
        print("Not Weird")
    elif 6 <= n <= 20:
        print("Weird")
    else:
        print("Not Weird")
# Out:
# Enter a number:  5
# Weird

# %%
a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = float(input("Enter side c: "))

if (a + b > c) and (a + c > b) and (b + c > a):
    print("Valid")
else:
    print("Invalid")
# Out:
# Enter side a:  6
# Enter side b:  8
# Enter side c:  6
# Valid

# %%
a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = float(input("Enter side c: "))

if a == b == c:
    print("Equilateral")
elif a == b or b == c or a == c:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# Enter side a:  5.5
# Enter side b:  6.5
# Enter side c:  7
# Scalene

# %%
units = int(input("Enter units consumed: "))

bill = 0

if units <= 100:
    bill = units * 5
elif units <= 200:
    bill = (100 * 5) + ((units - 100) * 7)
else:
    bill = (100 * 5) + (100 * 7) + ((units - 200) * 10)

print("Total bill = ₹", bill)
# Out:
# Enter units consumed:  600
# Total bill = ₹ 5200

# %%
salary = float(input("Enter salary: "))
years = int(input("Enter years of service: "))

if years >= 5:
    bonus = salary * 0.10
else:
    bonus = salary * 0.05

final_salary = salary + bonus

print("Bonus =", bonus)
print("Final Salary =", final_salary)
# Out:
# Enter salary:  50000
# Enter years of service:  20
# Bonus = 5000.0
# Final Salary = 55000.0

# %%
balance = float(input("Enter account balance: "))
withdraw = float(input("Enter withdrawal amount: "))

if (withdraw % 100 == 0) and (withdraw <= balance) and (balance - withdraw >= 500):
    print("Transaction Successful")
else:
    print("Transaction Failed")
# Out:
# Enter account balance:  28000
# Enter withdrawal amount:  28000
# Transaction Failed

# %%
a = float(input("Enter value of a: "))
b = float(input("Enter value of b: "))
c = float(input("Enter value of c: "))

D = b**2 - 4*a*c

if D > 0:
    print("Real and Distinct")
elif D == 0:
    print("Real and Equal")
else:
    print("Imaginary")
# Out:
# Enter value of a:  6.5
# Enter value of b:  7.5
# Enter value of c:  8.6
# Imaginary

# %%
amount = float(input("Enter purchase amount: "))

if amount >= 5000:
    discount = amount * 0.20
elif amount >= 2000:
    discount = amount * 0.10
else:
    discount = 0

final_amount = amount - discount

print("Discount =", discount)
print("Final Amount =", final_amount)
# Out:
# Enter purchase amount:  41750
# Discount = 8350.0
# Final Amount = 33400.0

# %%
while True:
    print("\nMenu:")
    print("1. Check Even/Odd")
    print("2. Check Positive/Negative")
    print("3. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        num = int(input("Enter a number: "))
        if num % 2 == 0:
            print("Even")
        else:
            print("Odd")

    elif choice == 2:
        num = int(input("Enter a number: "))
        if num > 0:
            print("Positive")
        elif num < 0:
            print("Negative")
        else:
            print("Zero")

    elif choice == 3:
        print("Exiting program...")
        break

    else:
        print("Invalid choice, try again!")
# Out:
# Menu:
# 1. Check Even/Odd
# 2. Check Positive/Negative
# 3. Exit
# Enter your choice:  1
# Enter a number:  2
# Even
#
# Menu:
# 1. Check Even/Odd
# 2. Check Positive/Negative
# 3. Exit
# Enter your choice:  2
# Enter a number:  -99
# Negative
#
# Menu:
# 1. Check Even/Odd
# 2. Check Positive/Negative
# 3. Exit
# Enter your choice:  3
# Exiting program...

# %%
correct_username = "admin"
correct_password = "1234"


username = input("Enter username: ")
password = input("Enter password: ")

if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username:  RAM RAM
# Enter password:  BSDK@999
# Invalid Credentials
